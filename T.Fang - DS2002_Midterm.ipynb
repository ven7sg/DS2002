# %%
# Tamera Fang (ven7sg) - DS2002 Midterm Project 
# This project focuses on extracting, transforming, and loading (ETL) data from multiple sources including MySQL, MongoDB, and CSV files into a data warehouse. 
# In this notebook, we are exploring sales data, customer information, track metadata, and album details from the Chinook database. 
# The goal is to understand how the data from different sources can be merged, cleaned, and analyzed to provide insights like total sales across countries, top customers, and average song lengths.

# %%
# INSTALL LIBRARIES

# %%
# !pip install mysql-connector-python
# !pip install sqlalchemy
# !pip install pymongo[srv]
# !pip install pandas
# !pip install matplotlib
# !pip install cryptography
# !pip install PyMySQL
# Out:
# Requirement already satisfied: mysql-connector-python in /opt/miniconda3/lib/python3.12/site-packages (9.1.0)
# Requirement already satisfied: sqlalchemy in /opt/miniconda3/lib/python3.12/site-packages (2.0.35)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/miniconda3/lib/python3.12/site-packages (from sqlalchemy) (4.11.0)
# zsh:1: no matches found: pymongo[srv]
# Requirement already satisfied: pandas in /opt/miniconda3/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/miniconda3/lib/python3.12/site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/miniconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda3/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in /opt/miniconda3/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: cryptography in /opt/miniconda3/lib/python3.12/site-packages (41.0.7)
# Requirement already satisfied: cffi>=1.12 in /opt/miniconda3/lib/python3.12/site-packages (from cryptography) (1.16.0)
# Requirement already satisfied: pycparser in /opt/miniconda3/lib/python3.12/site-packages (from cffi>=1.12->cryptography) (2.21)
# Requirement already satisfied: PyMySQL in /opt/miniconda3/lib/python3.12/site-packages (1.1.1)

# %%
# IMPORT LIBRARIES

# %%
import os
import pymysql
import mysql.connector
import sqlalchemy
from sqlalchemy import create_engine
import pymongo
import datetime
import json
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
print(f"Running SQL Alchemy Version: {sqlalchemy.__version__}")
print(f"Running PyMongo Version: {pymongo.__version__}")
# Out:
# Running SQL Alchemy Version: 2.0.35
# Running PyMongo Version: 4.10.1

# %%
# SQL ARGS

# %%
host_name = "localhost"
host_ip = "127.0.0.1"
port = "3306"

user_id = "root"
pwd = "Passw0rd123"
db_name = "chinook"

# %%
# TEST CONNECTION

# %%
import cryptography
import pymysql
print("PyMySQL version:", pymysql.__version__)

try:
    connection = pymysql.connect(
        host="localhost",
        user="root",
        password="Passw0rd123",
        database="chinook"
    )
    print("Connection successful!")
    connection.close()
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# PyMySQL version: 1.0.2
# Connection successful!

# %%
# IMPORT DATA FROM SQL

# %%
# RETRIEVE DATAFRAME FROM SQL
def get_sqldf(host_name, user_id, pwd, db_name, sqlQuery):
    try:
        conn = pymysql.connect(host=host_name, user=user_id, password=pwd, database=db_name)
        df = pd.read_sql(sqlQuery, conn)
        conn.close()
        return df
    except:
        print("Error. Check your connection.")

# %%
# INVOICE TABLE 
df_invoice = get_sqldf(host_name, user_id, pwd, db_name, ("SELECT * FROM invoice order by CustomerId;"))
df_invoice.head()
# Out:
#    InvoiceId  CustomerId InvoiceDate                   BillingAddress  \
# 0         98           1  2010-03-11  Av. Brigadeiro Faria Lima, 2170
# 1        121           1  2010-06-13  Av. Brigadeiro Faria Lima, 2170
# 2        143           1  2010-09-15  Av. Brigadeiro Faria Lima, 2170
# 3        195           1  2011-05-06  Av. Brigadeiro Faria Lima, 2170
# 4        316           1  2012-10-27  Av. Brigadeiro Faria Lima, 2170
#
#            BillingCity BillingState BillingCountry BillingPostalCode  Total
# 0  São José dos Campos           SP         Brazil         12227-000   3.98
# 1  São José dos Campos           SP         Brazil         12227-000   3.96
# 2  São José dos Campos           SP         Brazil         12227-000   5.94
# 3  São José dos Campos           SP         Brazil         12227-000   0.99
# 4  São José dos Campos           SP         Brazil         12227-000   1.98

# %%
# CUSTOMER TABLE
df_customer = get_sqldf(host_name, user_id, pwd, db_name, ("SELECT * FROM customer order by CustomerId;"))
df_customer.head()
# Out:
#    CustomerId  FirstName     LastName  \
# 0           1       Luís    Gonçalves
# 1           2     Leonie       Köhler
# 2           3   François     Tremblay
# 3           4      Bjørn       Hansen
# 4           5  František  Wichterlová
#
#                                             Company  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.
# 1                                              None
# 2                                              None
# 3                                              None
# 4                                  JetBrains s.r.o.
#
#                            Address                 City State         Country  \
# 0  Av. Brigadeiro Faria Lima, 2170  São José dos Campos    SP          Brazil
# 1          Theodor-Heuss-Straße 34            Stuttgart  None         Germany
# 2                1498 rue Bélanger             Montréal    QC          Canada
# 3                 Ullevålsveien 14                 Oslo  None          Norway
# 4                    Klanova 9/506               Prague  None  Czech Republic
#
#   PostalCode               Phone                 Fax  \
# 0  12227-000  +55 (12) 3923-5555  +55 (12) 3923-5566
# 1      70174    +49 0711 2842222                None
# 2    H2G 1A7   +1 (514) 721-4711                None
# 3       0171     +47 22 44 22 22                None
# 4      14700    +420 2 4172 5555    +420 2 4172 5555
#
#                       Email  SupportRepId
# 0      luisg@embraer.com.br             3
# 1     leonekohler@surfeu.de             5
# 2       ftremblay@gmail.com             3
# 3     bjorn.hansen@yahoo.no             4
# 4  frantisekw@jetbrains.com             4

# %%
# FACT TABLE 
conn = pymysql.connect(host=host_name, user=user_id, password=pwd, database=db_name)
df_invoice_fct = pd.read_sql("SELECT * FROM invoice order by InvoiceDate;", conn)
conn.close()
df_invoice_fct.head()
# Out:
#    InvoiceId  CustomerId InvoiceDate           BillingAddress BillingCity  \
# 0          1           2  2009-01-01  Theodor-Heuss-Straße 34   Stuttgart
# 1          2           4  2009-01-02         Ullevålsveien 14        Oslo
# 2          3           8  2009-01-03          Grétrystraat 63    Brussels
# 3          4          14  2009-01-06           8210 111 ST NW    Edmonton
# 4          5          23  2009-01-11          69 Salem Street      Boston
#
#   BillingState BillingCountry BillingPostalCode  Total
# 0         None        Germany             70174   1.98
# 1         None         Norway              0171   3.96
# 2         None        Belgium              1000   5.94
# 3           AB         Canada           T6G 2C7   8.91
# 4           MA            USA              2113  13.86

# %%
# IMPORT DATA FROM MONGODB

# %%
mysql_uid = "root"
mysql_pwd = "Passw0rd123"
atlas_cluster_name = "cluster0.kqsmdw7"
atlas_default_dbname = "local"
atlas_user_name = "ven7sg"
atlas_password = "Passw0rd123"
conn_str = {"local" : f"mongodb://localhost:27017/",
    "atlas" : f"mongodb+srv://{atlas_user_name}:{atlas_password}@{atlas_cluster_name}.mongodb.net"}
src_dbname = "chinook"
dst_dbname = "chinook_dw"
print(f"Local Connection String: {conn_str['local']}")
# Out:
# Local Connection String: mongodb://localhost:27017/

# %%
def get_mongo_dataframe(connect_str, db_name, collection, query):
    try:
        '''Create a connection to MongoDB'''
        client = pymongo.MongoClient(connect_str)
    
        '''Query MongoDB, and fill a python list with documents to create a dataframe'''
        db = client[db_name]
        df = pd.DataFrame(list(db[collection].find(query)))
        df.drop(['_id'], axis=1, inplace=True)
        client.close()
        return df
    except:
        print('Error: failure to get dataframe in MongoDB')

# %%
client = pymongo.MongoClient(conn_str["atlas"])
db = client[src_dbname]
data_dir = os.path.join("/Users/tamerafang/Desktop/DS2002_Midterm")

# %%
# TRACK TABLE
json_files = {"track" : 'Track.json'}

for file in json_files:
    try:
        db.drop_collection(file)
        json_file = os.path.join(data_dir, json_files[file])
        with open(json_file, 'r') as openfile:
            json_object = json.load(openfile)
            file = db[file]
            result = file.insert_many(json_object)
            print(f"{file} was successfully loaded.")
    except:
        print('Error. Failure to retrieve JSON file.')
        
client.close()
# Out:
# Collection(Database(MongoClient(host=['ac-jg6lcfb-shard-00-00.kqsmdw7.mongodb.net:27017', 'ac-jg6lcfb-shard-00-02.kqsmdw7.mongodb.net:27017', 'ac-jg6lcfb-shard-00-01.kqsmdw7.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-tm12uj-shard-0', tls=True), 'chinook'), 'track') was successfully loaded.

# %%
query = {}
collection = "track"

df_track = get_mongo_dataframe(conn_str['atlas'], src_dbname, collection, query) 
df_track.head(2)
# Out:
#                              __href  \
# 0  /db/Chinook/Track/TrackId/1.json
# 1  /db/Chinook/Track/TrackId/2.json
#
#                                            MediaType  \
# 0  {'__href': '/db/Chinook/Track/TrackId/1/MediaT...
# 1  {'__href': '/db/Chinook/Track/TrackId/2/MediaT...
#
#                                                Genre  \
# 0  {'__href': '/db/Chinook/Track/TrackId/1/Genre....
# 1  {'__href': '/db/Chinook/Track/TrackId/2/Genre....
#
#                                                Album  TrackId  \
# 0  {'__href': '/db/Chinook/Track/TrackId/1/Album....        1
# 1  {'__href': '/db/Chinook/Track/TrackId/2/Album....        2
#
#                                              Name  AlbumId  MediaTypeId  \
# 0  For Those About To Rock (We Salute You) - TEST        1            1
# 1                               Balls to the Wall        2            2
#
#    GenreId                                   Composer  Milliseconds     Bytes  \
# 0        1  Angus Young, Malcolm Young, Brian Johnson        343719  11170334
# 1        1                                       None        342562   5510424
#
#    UnitPrice                                      PlaylistTrack  \
# 0       0.99  {'__href': '/db/Chinook/Track/TrackId/1/Playli...
# 1       0.99  {'__href': '/db/Chinook/Track/TrackId/2/Playli...
#
#                                          InvoiceLine
# 0  {'__href': '/db/Chinook/Track/TrackId/1/Invoic...
# 1  {'__href': '/db/Chinook/Track/TrackId/2/Invoic...

# %%
# IMPORT DATA FROM CSV

# %%
# ARTIST TABLE
df_artist = pd.read_csv("/Users/tamerafang/Desktop/DS2002_Midterm/Artist.csv")
df_artist.head(5)
# Out:
#    ArtistId               Name
# 0         1              AC/DC
# 1         2             Accept
# 2         3          Aerosmith
# 3         4  Alanis Morissette
# 4         5    Alice In Chains

# %%
# ALBUM TABLE
df_album = pd.read_csv("/Users/tamerafang/Desktop/DS2002_Midterm/Album.csv")
df_album.head(5)
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3

# %%
# RENAMING AND DELETING COLUMNS

# %%
df_artist.rename(columns={"ArtistId":"Artist_Key"}, inplace=True)
df_artist.head()
# Out:
#    Artist_Key               Name
# 0           1              AC/DC
# 1           2             Accept
# 2           3          Aerosmith
# 3           4  Alanis Morissette
# 4           5    Alice In Chains

# %%
df_album.rename(columns={"AlbumId":"Album_Key","ArtistId":"Artist_Key"}, inplace=True)
df_album.head()
# Out:
#    Album_Key                                  Title  Artist_Key
# 0          1  For Those About To Rock We Salute You           1
# 1          2                      Balls to the Wall           2
# 2          3                      Restless and Wild           2
# 3          4                      Let There Be Rock           1
# 4          5                               Big Ones           3

# %%
df_invoice.rename(columns={"InvoiceId":"Invoice_Key","CustomerId":"Customer_Key"}, inplace=True)
df_invoice.drop(["BillingAddress","BillingState"],axis=1, inplace=True)
df_invoice.head()
# Out:
#    Invoice_Key  Customer_Key InvoiceDate          BillingCity BillingCountry  \
# 0           98             1  2010-03-11  São José dos Campos         Brazil
# 1          121             1  2010-06-13  São José dos Campos         Brazil
# 2          143             1  2010-09-15  São José dos Campos         Brazil
# 3          195             1  2011-05-06  São José dos Campos         Brazil
# 4          316             1  2012-10-27  São José dos Campos         Brazil
#
#   BillingPostalCode  Total
# 0         12227-000   3.98
# 1         12227-000   3.96
# 2         12227-000   5.94
# 3         12227-000   0.99
# 4         12227-000   1.98

# %%
df_customer.rename(columns={"CustomerId":"Customer_Key"}, inplace=True)
df_customer.drop(["Address","State","City","Country","PostalCode"], axis=1, inplace=True)
df_customer.head()
# Out:
#    Customer_Key  FirstName     LastName  \
# 0             1       Luís    Gonçalves
# 1             2     Leonie       Köhler
# 2             3   François     Tremblay
# 3             4      Bjørn       Hansen
# 4             5  František  Wichterlová
#
#                                             Company               Phone  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.  +55 (12) 3923-5555
# 1                                              None    +49 0711 2842222
# 2                                              None   +1 (514) 721-4711
# 3                                              None     +47 22 44 22 22
# 4                                  JetBrains s.r.o.    +420 2 4172 5555
#
#                   Fax                     Email  SupportRepId
# 0  +55 (12) 3923-5566      luisg@embraer.com.br             3
# 1                None     leonekohler@surfeu.de             5
# 2                None       ftremblay@gmail.com             3
# 3                None     bjorn.hansen@yahoo.no             4
# 4    +420 2 4172 5555  frantisekw@jetbrains.com             4

# %%
df_track.drop(['__href', 'MediaType', 'Genre', 'Album','PlaylistTrack','InvoiceLine'], axis=1, inplace=True)
df_track.rename(columns={"TrackId":"Track_Key","AlbumId":"Album_Key","MediaTypeId":"MediaType_Key","GenreId":"Genre_Key"},inplace=True)
df_track.head()
# Out:
#    Track_Key                                            Name  Album_Key  \
# 0          1  For Those About To Rock (We Salute You) - TEST          1
# 1          2                               Balls to the Wall          2
# 2          3                                 Fast As a Shark          3
# 3          4                               Restless and Wild          3
# 4          5                            Princess of the Dawn          3
#
#    MediaType_Key  Genre_Key  \
# 0              1          1
# 1              2          1
# 2              2          1
# 3              2          1
# 4              2          1
#
#                                             Composer  Milliseconds     Bytes  \
# 0          Angus Young, Malcolm Young, Brian Johnson        343719  11170334
# 1                                               None        342562   5510424
# 2  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619   3990994
# 3  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051   4331779
# 4                         Deaffy & R.A. Smith-Diesel        375418   6290521
#
#    UnitPrice
# 0       0.99
# 1       0.99
# 2       0.99
# 3       0.99
# 4       0.99

# %%
# MERGING TABLES TO MAKE DIMENSION TABLES

# %%
# MERGE df_customer and df_invoice

# %%
dim_customers = pd.merge(df_invoice, df_customer, on = "Customer_Key", how = "inner")
dim_customers.head()
# Out:
#    Invoice_Key  Customer_Key InvoiceDate          BillingCity BillingCountry  \
# 0           98             1  2010-03-11  São José dos Campos         Brazil
# 1          121             1  2010-06-13  São José dos Campos         Brazil
# 2          143             1  2010-09-15  São José dos Campos         Brazil
# 3          195             1  2011-05-06  São José dos Campos         Brazil
# 4          316             1  2012-10-27  São José dos Campos         Brazil
#
#   BillingPostalCode  Total FirstName   LastName  \
# 0         12227-000   3.98      Luís  Gonçalves
# 1         12227-000   3.96      Luís  Gonçalves
# 2         12227-000   5.94      Luís  Gonçalves
# 3         12227-000   0.99      Luís  Gonçalves
# 4         12227-000   1.98      Luís  Gonçalves
#
#                                             Company               Phone  \
# 0  Embraer - Empresa Brasileira de Aeronáutica S.A.  +55 (12) 3923-5555
# 1  Embraer - Empresa Brasileira de Aeronáutica S.A.  +55 (12) 3923-5555
# 2  Embraer - Empresa Brasileira de Aeronáutica S.A.  +55 (12) 3923-5555
# 3  Embraer - Empresa Brasileira de Aeronáutica S.A.  +55 (12) 3923-5555
# 4  Embraer - Empresa Brasileira de Aeronáutica S.A.  +55 (12) 3923-5555
#
#                   Fax                 Email  SupportRepId
# 0  +55 (12) 3923-5566  luisg@embraer.com.br             3
# 1  +55 (12) 3923-5566  luisg@embraer.com.br             3
# 2  +55 (12) 3923-5566  luisg@embraer.com.br             3
# 3  +55 (12) 3923-5566  luisg@embraer.com.br             3
# 4  +55 (12) 3923-5566  luisg@embraer.com.br             3

# %%
# MERGE df_artist and df_album

# %%
dim_artstats = pd.merge(df_album, df_artist, on="Artist_Key", how="inner")
dim_artstats.head()
# Out:
#    Album_Key                                  Title  Artist_Key       Name
# 0          1  For Those About To Rock We Salute You           1      AC/DC
# 1          4                      Let There Be Rock           1      AC/DC
# 2          2                      Balls to the Wall           2     Accept
# 3          3                      Restless and Wild           2     Accept
# 4          5                               Big Ones           3  Aerosmith

# %%
# MERGE df_album and df_track

# %%
dim_alb_track = pd.merge(df_track,df_album,on="Album_Key", how="inner")
dim_alb_track.head()
# Out:
#    Track_Key                                            Name  Album_Key  \
# 0          1  For Those About To Rock (We Salute You) - TEST          1
# 1          6                           Put The Finger On You          1
# 2          7                                 Let's Get It Up          1
# 3          8                                Inject The Venom          1
# 4          9                                      Snowballed          1
#
#    MediaType_Key  Genre_Key                                   Composer  \
# 0              1          1  Angus Young, Malcolm Young, Brian Johnson
# 1              1          1  Angus Young, Malcolm Young, Brian Johnson
# 2              1          1  Angus Young, Malcolm Young, Brian Johnson
# 3              1          1  Angus Young, Malcolm Young, Brian Johnson
# 4              1          1  Angus Young, Malcolm Young, Brian Johnson
#
#    Milliseconds     Bytes  UnitPrice                                  Title  \
# 0        343719  11170334       0.99  For Those About To Rock We Salute You
# 1        205662   6713451       0.99  For Those About To Rock We Salute You
# 2        233926   7636561       0.99  For Those About To Rock We Salute You
# 3        210834   6852860       0.99  For Those About To Rock We Salute You
# 4        203102   6599424       0.99  For Those About To Rock We Salute You
#
#    Artist_Key
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
# LOAD DIMENSION TABLES BACK INTO SQL

# %%
# INSERT dim_customers INTO chinook_dw INTO SQL, DECLARE PK

# %%
dw_name = 'chinook_dw'

# %%
conn_string = f'mysql+pymysql://{user_id}:{pwd}@{host_name}/{dw_name}'
sqlEngine = create_engine(conn_string, pool_recycle = 3600)
connection = sqlEngine.connect()
dim_customers.to_sql('dim_customers', connection, index=False, if_exists='replace')
sqlEngine.execute(f"ALTER TABLE {'dim_customers'} ADD PRIMARY KEY ({'Invoice_Key'});")
connection.close()

# %%
# INSERT dim_artstats INTO chinook_dw INTO SQL, DECLARE PK

# %%
conn_string = f'mysql+pymysql://{user_id}:{pwd}@{host_name}/{dw_name}'
sqlEngine = create_engine(conn_string, pool_recycle = 3600)
connection = sqlEngine.connect()
dim_artstats.to_sql('dim_artstats', connection, index=False, if_exists='replace')
sqlEngine.execute(f"ALTER TABLE {'dim_artStats'} ADD PRIMARY KEY ({'Album_Key'});")
connection.close()

# %%
# INSERT dim_alb_track INTO chinook_dw INTO SQL, DECLARE PK

# %%
conn_string = f'mysql+pymysql://{user_id}:{pwd}@{host_name}/{dw_name}'
sqlEngine = create_engine(conn_string, pool_recycle = 3600)
connection = sqlEngine.connect()
dim_alb_track.to_sql('dim_alb_track', connection, index=False, if_exists='replace')
sqlEngine.execute(f"ALTER TABLE {'dim_alb_track'} ADD PRIMARY KEY ({'Track_Key'});")
connection.close()

# %%
# VERIFY dim_customers IS IN chinook_dw IN SQL

# %%
conn = pymysql.connect(host=host_name, user=user_id, password=pwd, database=dw_name)
df_dim_customers = pd.read_sql("SELECT * FROM dim_customers order by Invoice_Key;", conn)
conn.close()
df_dim_customers.head()
# Out:
#    Invoice_Key  Customer_Key InvoiceDate BillingCity BillingCountry  \
# 0            1             2  2009-01-01   Stuttgart        Germany
# 1            2             4  2009-01-02        Oslo         Norway
# 2            3             8  2009-01-03    Brussels        Belgium
# 3            4            14  2009-01-06    Edmonton         Canada
# 4            5            23  2009-01-11      Boston            USA
#
#   BillingPostalCode  Total FirstName LastName Company              Phone  \
# 0             70174   1.98    Leonie   Köhler    None   +49 0711 2842222
# 1              0171   3.96     Bjørn   Hansen    None    +47 22 44 22 22
# 2              1000   5.94      Daan  Peeters    None   +32 02 219 03 03
# 3           T6G 2C7   8.91      Mark  Philips   Telus  +1 (780) 434-4554
# 4              2113  13.86      John   Gordon    None  +1 (617) 522-1333
#
#                  Fax                   Email  SupportRepId
# 0               None   leonekohler@surfeu.de             5
# 1               None   bjorn.hansen@yahoo.no             4
# 2               None   daan_peeters@apple.be             4
# 3  +1 (780) 434-5565      mphilips12@shaw.ca             5
# 4               None  johngordon22@yahoo.com             4

# %%
# VERIFY dim_artstats IS IN chinook_dw IN SQL

# %%
conn = pymysql.connect(host=host_name, user=user_id, password=pwd, database=dw_name)
df_dim_artstats = pd.read_sql("SELECT * FROM dim_artstats order by Album_Key;", conn)
conn.close()
df_dim_artstats.head()
# Out:
#    Album_Key                                  Title  Artist_Key       Name
# 0          1  For Those About To Rock We Salute You           1      AC/DC
# 1          2                      Balls to the Wall           2     Accept
# 2          3                      Restless and Wild           2     Accept
# 3          4                      Let There Be Rock           1      AC/DC
# 4          5                               Big Ones           3  Aerosmith

# %%
# verify that dim_alb_track is in chinook_dw in sql

# %%
conn = pymysql.connect(host=host_name, user=user_id, password=pwd, database=dw_name)
df_dim_alb_track = pd.read_sql("SELECT * FROM dim_alb_track order by Track_Key;", conn)
conn.close()
df_dim_alb_track.head()
# Out:
#    Track_Key                                            Name  Album_Key  \
# 0          1  For Those About To Rock (We Salute You) - TEST          1
# 1          2                               Balls to the Wall          2
# 2          3                                 Fast As a Shark          3
# 3          4                               Restless and Wild          3
# 4          5                            Princess of the Dawn          3
#
#    MediaType_Key  Genre_Key  \
# 0              1          1
# 1              2          1
# 2              2          1
# 3              2          1
# 4              2          1
#
#                                             Composer  Milliseconds     Bytes  \
# 0          Angus Young, Malcolm Young, Brian Johnson        343719  11170334
# 1                                               None        342562   5510424
# 2  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619   3990994
# 3  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051   4331779
# 4                         Deaffy & R.A. Smith-Diesel        375418   6290521
#
#    UnitPrice                                  Title  Artist_Key
# 0       0.99  For Those About To Rock We Salute You           1
# 1       0.99                      Balls to the Wall           2
# 2       0.99                      Restless and Wild           2
# 3       0.99                      Restless and Wild           2
# 4       0.99                      Restless and Wild           2

# %%
# DATE DIMENSION, FACT TABLE

# %%
# CREATE DATE KEYS
date_list = []
counter = 0

if df_invoice_fct['InvoiceDate'][0] == df_invoice_fct['InvoiceDate'][1]:
    counter = counter
    date_list.append(counter)
else:
    counter += 1
    date_list.append(counter)

for i in range(1, len(df_invoice_fct)-1):
    if df_invoice_fct['InvoiceDate'][i] == df_invoice_fct['InvoiceDate'][i+1]:
        counter == counter
        date_list.append(counter)
    else:
        counter += 1
        date_list.append(counter)

date_list.insert(0, 0)
df_invoice_fct['DateKey'] = date_list

# DROP DATE COLUMN
df_invoice_fct.drop(['InvoiceDate'], axis=1, inplace=True)

# FINAL FACT TABLE WITH DATE DIMENSION 
df_invoice_fct.head(30)
# Out:
#     InvoiceId  CustomerId             BillingAddress    BillingCity  \
# 0           1           2    Theodor-Heuss-Straße 34      Stuttgart
# 1           2           4           Ullevålsveien 14           Oslo
# 2           3           8            Grétrystraat 63       Brussels
# 3           4          14             8210 111 ST NW       Edmonton
# 4           5          23            69 Salem Street         Boston
# 5           6          37           Berger Straße 10      Frankfurt
# 6           7          38        Barbarossastraße 19         Berlin
# 7           8          40             8, Rue Hanovre          Paris
# 8           9          42     9, Place Louis Barthou       Bordeaux
# 9          10          46           3 Chatham Street         Dublin
# 10         11          52          202 Hoxton Street         London
# 11         12           2    Theodor-Heuss-Straße 34      Stuttgart
# 12         13          16  1600 Amphitheatre Parkway  Mountain View
# 13         14          17            1 Microsoft Way        Redmond
# 14         15          19            1 Infinite Loop      Cupertino
# 15         16          21           801 W 4th Street           Reno
# 16         17          25      319 N. Frances Street        Madison
# 17         18          31      194A Chain Lake Drive        Halifax
# 18         19          40             8, Rue Hanovre          Paris
# 19         20          54             110 Raeburn Pl     Edinburgh
# 20         21          55          421 Bourke Street         Sidney
# 21         22          57            Calle Lira, 198       Santiago
# 22         23          59          3,Raj Bhavan Road      Bangalore
# 23         24           4           Ullevålsveien 14           Oslo
# 24         25          10  Rua Dr. Falcão Filho, 155      São Paulo
# 25         26          19            1 Infinite Loop      Cupertino
# 26         27          33             5112 48 Street    Yellowknife
# 27         28          34         Rua da Assunção 53         Lisbon
# 28         29          36         Tauentzienstraße 8         Berlin
# 29         30          38        Barbarossastraße 19         Berlin
#
#    BillingState  BillingCountry BillingPostalCode  Total  DateKey
# 0          None         Germany             70174   1.98        0
# 1          None          Norway              0171   3.96        1
# 2          None         Belgium              1000   5.94        2
# 3            AB          Canada           T6G 2C7   8.91        3
# 4            MA             USA              2113  13.86        4
# 5          None         Germany             60316   0.99        5
# 6          None         Germany             10779   1.98        6
# 7          None          France             75002   1.98        6
# 8          None          France             33000   3.96        7
# 9        Dublin         Ireland              None   5.94        8
# 10         None  United Kingdom            N1 5LH   8.91        9
# 11         None         Germany             70174  13.86       10
# 12           CA             USA        94043-1351   0.99       11
# 13           WA             USA        98052-8300   1.98       12
# 14           CA             USA             95014   1.98       12
# 15           NV             USA             89503   3.96       13
# 16           WI             USA             53703   5.94       14
# 17           NS          Canada           B3S 1C5   8.91       15
# 18         None          France             75002  13.86       16
# 19         None  United Kingdom           EH4 1HH   0.99       17
# 20          NSW       Australia              2010   1.98       18
# 21         None           Chile              None   1.98       18
# 22         None           India            560001   3.96       19
# 23         None          Norway              0171   5.94       20
# 24           SP          Brazil         01007-010   8.91       21
# 25           CA             USA             95014  13.86       22
# 26           NT          Canada           X1A 1N6   0.99       23
# 27         None        Portugal              None   1.98       24
# 28         None         Germany             10789   1.98       24
# 29         None         Germany             10779   3.96       25

# %%
# INSERT FINAL FACT TABLE INTO SQL, DECLARE PK

# %%
invoice_fact = df_invoice_fct
conn_string = f'mysql+pymysql://{user_id}:{pwd}@{host_name}/{dw_name}'
sqlEngine = create_engine(conn_string, pool_recycle = 3600)
connection = sqlEngine.connect()
invoice_fact.to_sql('invoice_fact', connection, index=False, if_exists='replace')
sqlEngine.execute(f"ALTER TABLE {'invoice_fact'} ADD PRIMARY KEY ({'InvoiceId'});")
connection.close()

# %%
# VERIFY fact table IS IN chinook_dw IN SQL

# %%
conn = pymysql.connect(host=host_name, user=user_id, password=pwd, database=dw_name)
invoice_fact = pd.read_sql("SELECT * FROM invoice_fact order by InvoiceId;", conn)
conn.close()
invoice_fact.head()
# Out:
#    InvoiceId  CustomerId           BillingAddress BillingCity BillingState  \
# 0          1           2  Theodor-Heuss-Straße 34   Stuttgart         None
# 1          2           4         Ullevålsveien 14        Oslo         None
# 2          3           8          Grétrystraat 63    Brussels         None
# 3          4          14           8210 111 ST NW    Edmonton           AB
# 4          5          23          69 Salem Street      Boston           MA
#
#   BillingCountry BillingPostalCode  Total  DateKey
# 0        Germany             70174   1.98        0
# 1         Norway              0171   3.96        1
# 2        Belgium              1000   5.94        2
# 3         Canada           T6G 2C7   8.91        3
# 4            USA              2113  13.86        4

# %%
# QUERIES - ANALYSIS

# %%
# TOTAL SALES FROM DIFFERENT COUNTRIES

# %%
conn = pymysql.connect(host=host_name, user=user_id, password=pwd, database=dw_name)
df_sales = pd.read_sql("select sum(Total),BillingCountry from chinook_dw.dim_customers group by BillingCountry;", conn)
conn.close()
df_sales
# Out:
#     sum(Total)  BillingCountry
# 0       156.48         Germany
# 1        39.62          Norway
# 2        37.62         Belgium
# 3       303.96          Canada
# 4       523.06             USA
# 5       195.10          France
# 6        45.62         Ireland
# 7       112.86  United Kingdom
# 8        37.62       Australia
# 9        46.62           Chile
# 10       75.26           India
# 11      190.10          Brazil
# 12       77.24        Portugal
# 13       40.62     Netherlands
# 14       37.62           Spain
# 15       38.62          Sweden
# 16       90.24  Czech Republic
# 17       41.62         Finland
# 18       37.62         Denmark
# 19       37.62           Italy
# 20       37.62          Poland
# 21       42.62         Austria
# 22       45.62         Hungary
# 23       37.62       Argentina

# %%
# TOP 3 CUSTOMERS BASED ON SALES

# %%
conn = pymysql.connect(host=host_name, user=user_id, password=pwd, database=dw_name)
df_customer_sales = pd.read_sql("select sum(Total),CustomerId from chinook_dw.invoice_fact group by CustomerId order by sum(Total) desc;", conn)
conn.close()
df_customer_sales.head(3)
# Out:
#    sum(Total)  CustomerId
# 0       49.62           6
# 1       47.62          26
# 2       46.62          57

# %%
# AVG LENGTH OF SONG, BASED ON COMPOSER

# %%
conn = pymysql.connect(host=host_name, user=user_id, password=pwd, database=dw_name)
df_length = pd.read_sql("select avg(Milliseconds),Composer from chinook_dw.dim_alb_track group by Composer;", conn)
conn.close()
df_length.head()
# Out:
#    avg(Milliseconds)                                           Composer
# 0           240041.5          Angus Young, Malcolm Young, Brian Johnson
# 1           342562.0                                               None
# 2           230619.0  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...
# 3           252051.0  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...
# 4           375418.0                         Deaffy & R.A. Smith-Diesel
